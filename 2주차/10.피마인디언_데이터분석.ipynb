# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# KFold (교차 검증을 사용하기 위해)
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold

# 교차검증 함수
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_validate

# 학습 데이터와 검증 데이터로 나누는 함수
from sklearn.model_selection import train_test_split

# 데이터 전처리
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# 하이퍼 파라미터 튜닝
from sklearn.model_selection import GridSearchCV

# 평가 함수
from sklearn.metrics import accuracy_score

# 머신러닝 알고리즘 - 분류
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# 머신러닝 알고리즘 - 회귀
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import  XGBRegressor

# 머신러닝 알고리즘 - 군집
from sklearn.cluster import KMeans
from sklearn.cluster import MeanShift

# 머신러닝 알고리즘 - 차원축소
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# 딥러닝 알고리즘 
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# 저장
import pickle

# 시간 모듈
import time

# 그래프 설정
# plt.rcParams['font.family'] = 'Malgun Gothic'   # 윈도우용
plt.rcParams['font.family'] = 'AppleGothic'   # 맥용
plt.rcParams['font.size'] = 16                  # 폰트 크기
plt.rcParams['figure.figsize'] = 10,8          # 그래프 크기
plt.rcParams['axes.unicode_minus'] = False     # - 기호 깨짐 방지


# 경고 메시지가 안나오게 하기
import warnings
warnings.filterwarnings('ignore')

# %%
# 데이터 불러오기
column_list = ['임신횟수','혈당','혈압','근육피부두께','인슐린','체질량','가족력','나이','당뇨여부']
df1 = pd.read_csv('../dataset/pima-indians-diabetes.csv',
                  names = column_list)
df1.head()
# Out:
#    임신횟수   혈당  혈압  근육피부두께  인슐린   체질량    가족력  나이  당뇨여부
# 0     6  148  72      35    0  33.6  0.627  50     1
# 1     1   85  66      29    0  26.6  0.351  31     0
# 2     8  183  64       0    0  23.3  0.672  32     1
# 3     1   89  66      23   94  28.1  0.167  21     0
# 4     0  137  40      35  168  43.1  2.288  33     1

# %%
# 전반적인 정보를 확인한다.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   임신횟수    768 non-null    int64
#  1   혈당      768 non-null    int64
#  2   혈압      768 non-null    int64
#  3   근육피부두께  768 non-null    int64
#  4   인슐린     768 non-null    int64
#  5   체질량     768 non-null    float64
#  6   가족력     768 non-null    float64
#  7   나이      768 non-null    int64
#  8   당뇨여부    768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 전반적인 통계 정보를 확인한다.
df1.describe()
# Out:
#              임신횟수          혈당          혈압      근육피부두께         인슐린         체질량  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#               가족력          나이        당뇨여부
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
# 컬럼간의 상관관계를 가져온다.
df1.corr()
# Out:
#             임신횟수        혈당        혈압    근육피부두께       인슐린       체질량       가족력  \
# 임신횟수    1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# 혈당      0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# 혈압      0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# 근육피부두께 -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# 인슐린    -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# 체질량     0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# 가족력    -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# 나이      0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# 당뇨여부    0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#               나이      당뇨여부
# 임신횟수    0.544341  0.221898
# 혈당      0.263514  0.466581
# 혈압      0.239528  0.065068
# 근육피부두께 -0.113970  0.074752
# 인슐린    -0.042163  0.130548
# 체질량     0.036242  0.292695
# 가족력     0.033561  0.173844
# 나이      1.000000  0.238356
# 당뇨여부    0.238356  1.000000

# %%
# 각 컬럼의 상관관계를 볼수 있는 그래프
# 첫번째 : 각 컬럼간 상관관계 수치를 가진 데이터프레임
# linewidths : 외관석 두께
# vmax = 색상의 농도
# cmap = 컬러맵
# linecolor : 외곽선
# annot : True를 주면 각 칸에 수치를 표시해준다.

sns.heatmap(df1.corr(), linewidths = 0.1, vmax = 0.5, cmap = plt.cm.gist_heat,
            linecolor = 'white', annot = True)
plt.show()

# %%
# 입력과 결과 데이터 나누기
X = df1.drop('당뇨여부', axis=1)
Y = df1['당뇨여부']

# %%
# 시드 설정
np.random.seed(3)
tf.random.set_seed(3)

# %%
# 모델 설정
model = Sequential()
# 입력층 (입력데이터 8개), 은닉층(node = 16)
model.add(Dense(16, input_dim = 8, activation = 'relu'))
# 은닉층 추가
model.add(Dense(14,activation='relu'))
# 은닉층 추가
model.add(Dense(12,activation='relu'))
# 은닉층 추가
model.add(Dense(10,activation='relu'))
# 은닉층 추가
model.add(Dense(8,activation='relu'))
# 은닉층 추가
model.add(Dense(6,activation='relu'))
# 은닉층 추가
model.add(Dense(4,activation='relu'))
# 출력층 (2진분류)
model.add(Dense(1,activation = 'sigmoid'))

# %%
# 모델 컴파일
model.compile(loss = 'binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 모델 실행
# 시작 시간
now = time.time()
model.fit(X,Y,epochs=200, batch_size=10, verbose = 0)

# 경과시간
print(f'경과시간 : {time.time() - now}')
# Out:
# 경과시간 : 8.363375902175903

# %%
# 정확도 확인
print(f'정확도 : {model.evaluate(X,Y)[1]}')
# Out:
# 24/24 [==============================] - 0s 645us/step - loss: 0.3256 - accuracy: 0.8555
# 정확도 : 0.85546875
